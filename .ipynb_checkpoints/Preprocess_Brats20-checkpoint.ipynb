# %%
import numpy as np 
import matplotlib.pyplot as plt
import os 
import glob 
import medpy.io
from utils import plot_comparison 
# %matplotlib inline
# Out:
# /home/kevinteng/anaconda3/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/kevinteng/anaconda3/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/kevinteng/anaconda3/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
storage_path = "/home/kevinteng/Desktop/ssd02/"
training_ds_path = storage_path+"MICCAI_BraTS2020_TrainingData/"
validation_ds_path = storage_path+"MICCAI_BraTS2020_ValidationData/"

# %%
patients = sorted(os.listdir(training_ds_path))
print("Training Patients count: {}".format(len(patients)))
# Out:
# Training Patients count: 371

# %%
imgs = []
for patient in patients:
    merge_00 = os.path.join(training_ds_path+patient+"/")
    for patient_imgs in sorted(os.listdir(merge_00)):
        merge_01 = os.path.join(merge_00+patient_imgs)
        patient_img01,_ = medpy.io.load(merge_01)
        imgs.append(patient_img01)
        print(merge_01)
    break
# Out:
# /home/kevinteng/Desktop/ssd02/MICCAI_BraTS2020_TrainingData/BraTS20_Training_001/BraTS20_Training_001_flair.nii.gz
# /home/kevinteng/Desktop/ssd02/MICCAI_BraTS2020_TrainingData/BraTS20_Training_001/BraTS20_Training_001_seg.nii.gz
# /home/kevinteng/Desktop/ssd02/MICCAI_BraTS2020_TrainingData/BraTS20_Training_001/BraTS20_Training_001_t1.nii.gz
# /home/kevinteng/Desktop/ssd02/MICCAI_BraTS2020_TrainingData/BraTS20_Training_001/BraTS20_Training_001_t1ce.nii.gz
# /home/kevinteng/Desktop/ssd02/MICCAI_BraTS2020_TrainingData/BraTS20_Training_001/BraTS20_Training_001_t2.nii.gz

# %%
mid = int(np.floor(155/2))
print(mid)
# Out:
# 77

# %%
#temprorary store images in list and cast to array 
imgs = np.array(imgs)

# %%
imgs[0].shape
# Out:
# (240, 240, 155)

# %%
captions = ["flair", "label", "t1", "t1ce", "t2"]
images = [i[:,:,mid] for i in imgs]
plot_comparison(images, captions, n_col=len(images), figsize=(20,20))
